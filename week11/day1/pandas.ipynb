# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("yasserh/housing-prices-dataset")

# print("Path to dataset files:", path)

# %%
df= pd.read_csv('Housing.csv', encoding='utf-8')

df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.head(5) #get five rows of the dataframe
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()  #get information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe() #get statistical description of the dataframe
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.tail(10) #get last ten rows of the dataframe
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 535  2100000  3360         2          1        1      yes        no       no
# 536  1960000  3420         5          1        2       no        no       no
# 537  1890000  1700         3          1        2      yes        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 539  1855000  2990         2          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df2=df[['price','area','bedrooms','bathrooms']]
df2.head(10)
# Out:
#       price   area  bedrooms  bathrooms
# 0  13300000   7420         4          2
# 1  12250000   8960         4          4
# 2  12250000   9960         3          2
# 3  12215000   7500         4          2
# 4  11410000   7420         4          1
# 5  10850000   7500         3          3
# 6  10150000   8580         4          3
# 7  10150000  16200         5          3
# 8   9870000   8100         4          1
# 9   9800000   5750         3          2

# %%
df3=df2.drop(['bathrooms'], axis=1)
df3.head(10)
# Out:
#       price   area  bedrooms
# 0  13300000   7420         4
# 1  12250000   8960         4
# 2  12250000   9960         3
# 3  12215000   7500         4
# 4  11410000   7420         4
# 5  10850000   7500         3
# 6  10150000   8580         4
# 7  10150000  16200         5
# 8   9870000   8100         4
# 9   9800000   5750         3

# %%
#ecxxtract one column

bathrooms = df['bathrooms']
df3['bathrooms'] = bathrooms * 5

df3.head(10)
# Out:
#       price   area  bedrooms  bathrooms
# 0  13300000   7420         4         10
# 1  12250000   8960         4         20
# 2  12250000   9960         3         10
# 3  12215000   7500         4         10
# 4  11410000   7420         4          5
# 5  10850000   7500         3         15
# 6  10150000   8580         4         15
# 7  10150000  16200         5         15
# 8   9870000   8100         4          5
# 9   9800000   5750         3         10

# %%
#filter data

result=df2[df2['area'] <= 8000]

result.head(10)
# Out:
#        price  area  bedrooms  bathrooms
# 0   13300000  7420         4          2
# 3   12215000  7500         4          2
# 4   11410000  7420         4          1
# 5   10850000  7500         3          3
# 9    9800000  5750         3          2
# 11   9681000  6000         4          3
# 12   9310000  6550         4          2
# 13   9240000  3500         4          2
# 14   9240000  7800         3          2
# 15   9100000  6000         4          1

# %%
#plot price vs area
plt.scatter(df2['area'], df2['price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Price vs Area')
plt.show()

# %%
df3.to_csv('housing_prices.csv', index=False)

# %%
df2.head(10)
# Out:
#       price   area  bedrooms  bathrooms
# 0  13300000   7420         4          2
# 1  12250000   8960         4          4
# 2  12250000   9960         3          2
# 3  12215000   7500         4          2
# 4  11410000   7420         4          1
# 5  10850000   7500         3          3
# 6  10150000   8580         4          3
# 7  10150000  16200         5          3
# 8   9870000   8100         4          1
# 9   9800000   5750         3          2

# %%
row1= df2.iloc[1] #accessing a specific row by index
row1
# Out:
# price        12250000
# area             8960
# bedrooms            4
# bathrooms           4
# Name: 1, dtype: int64

# %%
#extratc column

area=df2['area']
area
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df2=df.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df2.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df2['mainroad'] = df2['mainroad'].map({'yes': 1, 'no': 0})
df2['guestroom'] = df2['guestroom'].map({'yes': 1, 'no': 0})
df2['basement'] = df2['basement'].map({'yes': 1, 'no': 0})
df2['hotwaterheating'] = df2['hotwaterheating'].map({'yes': 1, 'no': 0})
df2['airconditioning'] = df2['airconditioning'].map({'yes': 1, 'no': 0})
df2['prefarea'] = df2['prefarea'].map({'yes': 1, 'no': 0})


# df2['mainroad'] = df2['mainroad'].astype(bool).astype(int)

# %%
df2.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
#predicting price of a house based on all columns


#preprocessing
furnishing_encoder= {'furnished': 2, 'semi-furnished': 1, 'unfurnished': 0}
df2['furnishingstatus'] = df2['furnishingstatus'].map(furnishing_encoder)

df2['furnishingstatus']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 540    0
# 541    1
# 542    0
# 543    2
# 544    0
# Name: furnishingstatus, Length: 545, dtype: int64

# %%
df2.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 2

# %%
x= df2.drop(['price'], axis=1)  # Features
y= df2['price']  # Target variable

x.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          0         0
# 1  8960         4          4        4         1          0         0
# 2  9960         3          2        2         1          0         1
# 3  7500         4          2        2         1          0         1
# 4  7420         4          1        2         1          1         1
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                0                1        2         1                 2
# 1                0                1        3         0                 2
# 2                0                0        2         1                 1
# 3                0                1        3         1                 2
# 4                0                1        2         0                 2

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
#split dataser into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436 entries, 46 to 102
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   area              436 non-null    int64
#  1   bedrooms          436 non-null    int64
#  2   bathrooms         436 non-null    int64
#  3   stories           436 non-null    int64
#  4   mainroad          436 non-null    int64
#  5   guestroom         436 non-null    int64
#  6   basement          436 non-null    int64
#  7   hotwaterheating   436 non-null    int64
#  8   airconditioning   436 non-null    int64
#  9   parking           436 non-null    int64
#  10  prefarea          436 non-null    int64
#  11  furnishingstatus  436 non-null    int64
# dtypes: int64(12)
# memory usage: 44.3 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, 316 to 155
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   area              109 non-null    int64
#  1   bedrooms          109 non-null    int64
#  2   bathrooms         109 non-null    int64
#  3   stories           109 non-null    int64
#  4   mainroad          109 non-null    int64
#  5   guestroom         109 non-null    int64
#  6   basement          109 non-null    int64
#  7   hotwaterheating   109 non-null    int64
#  8   airconditioning   109 non-null    int64
#  9   parking           109 non-null    int64
#  10  prefarea          109 non-null    int64
#  11  furnishingstatus  109 non-null    int64
# dtypes: int64(12)
# memory usage: 11.1 KB

# %%
results={}

# %%
#linear regression model
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train) #train the model

#evaluate the model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse= np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")

results['Linear Regression'] = {
    'Mean Squared Error': mse,
    'R-squared': r2,
    'Mean Absolute Error': mae,
    'Root Mean Squared Error': rmse
}
# Out:
# Mean Squared Error: 1771751116594.0344
# R-squared: 0.6494754192267804
# Mean Absolute Error: 979679.6912959903
# Root Mean Squared Error: 1331071.4167895103
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_

# %%
#decision tree regressor
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor()
dt_model.fit(x_train, y_train)  # Train the model

# Evaluate the model

y_pred = dt_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse= np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")

results['Decision Tree Regressor'] = {
    'Mean Squared Error': mse,
    'R-squared': r2,
    'Mean Absolute Error': mae,
    'Root Mean Squared Error': rmse
}
# Out:
# Mean Squared Error: 2986965151376.147
# R-squared: 0.40905655559395215
# Mean Absolute Error: 1265266.0550458715
# Root Mean Squared Error: 1728283.874650269

# %%
#random forest regressor
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)  # Train the model

# Evaluate the model
y_pred = rf_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse= np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")

results['Random Forest Regressor'] = {
    'Mean Squared Error': mse,
    'R-squared': r2,
    'Mean Absolute Error': mae,
    'Root Mean Squared Error': rmse
}
# Out:
# Mean Squared Error: 1956925181711.5183
# R-squared: 0.612840442148196
# Mean Absolute Error: 1024081.0328746178
# Root Mean Squared Error: 1398901.4195830664

# %%
#print params of rf model
print("Random Forest Regressor Parameters:")
print(rf_model.get_params())
# Out:
# Random Forest Regressor Parameters:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
#naive bayes regressor
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
nb_model.fit(x_train, y_train)  # Train the model

# Evaluate the model

y_pred = nb_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse= np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")

results['Naive Bayes Regressor'] = {
    'Mean Squared Error': mse,
    'R-squared': r2,
    'Mean Absolute Error': mae,
    'Root Mean Squared Error': rmse
}
# Out:
# Mean Squared Error: 2980027717889.908
# R-squared: 0.41042906268122326
# Mean Absolute Error: 1164922.0183486238
# Root Mean Squared Error: 1726275.6784157935
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)

# %%
results
# Out:
# {'Linear Regression': {'Mean Squared Error': 1771751116594.0344,
#   'R-squared': 0.6494754192267804,
#   'Mean Absolute Error': 979679.6912959903,
#   'Root Mean Squared Error': np.float64(1331071.4167895103)},
#  'Decision Tree Regressor': {'Mean Squared Error': 2986965151376.147,
#   'R-squared': 0.40905655559395215,
#   'Mean Absolute Error': 1265266.0550458715,
#   'Root Mean Squared Error': np.float64(1728283.874650269)},
#  'Random Forest Regressor': {'Mean Squared Error': 1956925181711.5183,
#   'R-squared': 0.612840442148196,
#   'Mean Absolute Error': 1024081.0328746178,
#   'Root Mean Squared Error': np.float64(1398901.4195830664)},
#  'Naive Bayes Regressor': {'Mean Squared Error': 2980027717889.908,
#   'R-squared': 0.41042906268122326,
#   'Mean Absolute Error': 1164922.0183486238,
#   'Root Mean Squared Error': np.float64(1726275.6784157935)}}

# %%
#plot graph for model comparison
plt.figure(figsize=(10, 6))
plt.barh(list(results.keys()), [v['R-squared'] for v in results.values()], color='skyblue')
plt.xlabel('R-squared')
plt.title('Model Comparison')
plt.show()

# %%
#tuning model
#selected the linear regression model for further tuning

param_grid= {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False],
    'n_jobs': [None, -1]
}

# %%
#tune random forest regressor

param_grid={
    'n_estimators': [50, 100, 200],
    'max_depth': [None,3,5,10, 15,20, 30],
    'min_samples_split': [1, 2, 5, 10],
    'min_samples_leaf': [1, 2, 3,5,10]
}

#tune
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_

print("Best parameters for Random Forest Regressor:", best_params)

#show metrics
best_rf_model = grid_search.best_estimator_
y_pred = best_rf_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Best parameters for Random Forest Regressor: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# Mean Squared Error: 2043589477824.679
# R-squared: 0.5956947122662984
# Mean Absolute Error: 1057948.125517567
# Root Mean Squared Error: 1429541.7020236517
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:516: FitFailedWarning:
# 525 fits failed out of a total of 2100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 525 fits failed with the following error:
# Traceback (most recent call last):
# ...

# %%
person={
    'name': 'Yasser',
    'age': 30,
    'city': 'Cairo',
    'profession': 'Data Scientist',
    'hobbies': ['coding', 'reading', 'traveling']
}
print(person)

import json
x=json.dumps(person)

# Save the JSON string to a file
with open('person.json', 'w') as file:
    file.write(x)
# Out:
# {'name': 'Yasser', 'age': 30, 'city': 'Cairo', 'profession': 'Data Scientist', 'hobbies': ['coding', 'reading', 'traveling']}

# %%
import json
x=open('person.json', 'r').read()
z= json.loads(x)
z
# Out:
# {'name': 'Yasser',
#  'age': 30,
#  'city': 'Cairo',
#  'profession': 'Data Scientist',
#  'hobbies': ['coding', 'reading', 'traveling']}
